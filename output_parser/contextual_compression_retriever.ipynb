# %%
pip install -U chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.8-cp39-abi3-macosx_11_0_arm64.whl (21.6 MB)
#      |████████████████████████████████| 21.6 MB 2.3 MB/s eta 0:00:01     |██████████████████████████      | 17.5 MB 2.1 MB/s eta 0:00:02
# Requirement already satisfied: numpy>=1.22.5 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (2.0.2)
# Requirement already satisfied: orjson>=3.9.12 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (3.11.5)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-macosx_11_0_universal2.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 2.6 MB/s eta 0:00:01
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (6.0.3)
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (4.67.3)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.2.0-cp39-cp39-macosx_11_0_arm64.whl (40 kB)
#      |████████████████████████████████| 40 kB 2.6 MB/s eta 0:00:01
# Collecting rich>=10.11.0
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 2.5 MB/s eta 0:00:01
# Collecting typer>=0.9.0
#   Downloading typer-0.23.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 1.9 MB/s eta 0:00:01
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: httpx>=0.27.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (4.15.0)
# Collecting jsonschema>=4.19.0
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 2.3 MB/s eta 0:00:01
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
#      |████████████████████████████████| 495 kB 1.7 MB/s eta 0:00:01
# Collecting pypika>=0.48.9
#   Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 18.6 MB/s eta 0:00:01
# Collecting pybase64>=1.4.1
#   Downloading pybase64-1.4.3-cp39-cp39-macosx_11_0_arm64.whl (31 kB)
# Collecting build>=1.0.3
#   Downloading build-1.4.4-py3-none-any.whl (25 kB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: pydantic>=2.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (2.13.0)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.39.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: tenacity>=8.2.3 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Collecting pydantic-settings>=2.0
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (20 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: grpcio>=1.58.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from chromadb) (1.80.0)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.4.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=24.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.7.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: certifi in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2026.2.25)
# Requirement already satisfied: anyio in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.1)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp39-cp39-macosx_11_0_arm64.whl (354 kB)
#      |████████████████████████████████| 354 kB 2.2 MB/s eta 0:00:01
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting attrs>=22.2.0
#   Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: requests in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.9.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Collecting flatbuffers
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: protobuf in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 3.2 MB/s eta 0:00:01
# Collecting opentelemetry-proto==1.41.1
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.8 MB/s eta 0:00:01
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Collecting opentelemetry-semantic-conventions==0.62b1
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from pydantic>=2.0->chromadb) (2.46.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 4.6 MB/s eta 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.2)
# Requirement already satisfied: filelock in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.3)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 4.4 MB/s eta 0:00:01
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.1.1-cp39-cp39-macosx_11_0_arm64.whl (396 kB)
#      |████████████████████████████████| 396 kB 3.5 MB/s eta 0:00:01
# Collecting uvloop>=0.15.1
#   Downloading uvloop-0.22.1-cp39-cp39-macosx_10_9_universal2.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.1 MB/s eta 0:00:01
# Collecting httptools>=0.6.3
#   Downloading httptools-0.7.1-cp39-cp39-macosx_11_0_arm64.whl (110 kB)
#      |████████████████████████████████| 110 kB 3.0 MB/s eta 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
#      |████████████████████████████████| 173 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 3.0 MB/s eta 0:00:01
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 2.9 MB/s eta 0:00:01
# Installing collected packages: rpds-py, opentelemetry-api, mdurl, attrs, referencing, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, mpmath, markdown-it-py, humanfriendly, click, websockets, websocket-client, watchfiles, uvloop, uvicorn, tomli, sympy, shellingham, rich, requests-oauthlib, pyproject-hooks, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-common, jsonschema-specifications, httptools, flatbuffers, durationpy, coloredlogs, annotated-doc, typer, pypika, pydantic-settings, pybase64, overrides, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, kubernetes, jsonschema, importlib-resources, build, bcrypt, chromadb
# Successfully installed annotated-doc-0.0.4 attrs-26.1.0 bcrypt-5.0.0 build-1.4.4 chromadb-1.5.8 click-8.1.8 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.12.19 httptools-0.7.1 humanfriendly-10.0 importlib-resources-6.5.2 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 kubernetes-35.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.2.0 mpmath-1.3.0 oauthlib-3.3.1 onnxruntime-1.19.2 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 overrides-7.7.0 pybase64-1.4.3 pydantic-settings-2.11.0 pypika-0.51.1 pyproject-hooks-1.2.0 referencing-0.36.2 requests-oauthlib-2.0.0 rich-15.0.0 rpds-py-0.27.1 shellingham-1.5.4 sympy-1.14.0 tomli-2.4.1 typer-0.23.2 uvicorn-0.39.0 uvloop-0.22.1 watchfiles-1.1.1 websocket-client-1.9.0 websockets-15.0.1
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/faisalhanif/Desktop/learning/lang-chain-structured-output/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_classic.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import LLMChainExtractor
from langchain_core.documents import Document
from langchain_huggingface import ChatHuggingFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_community.vectorstores import Chroma
#       2 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#       3 from langchain_classic.retrievers.contextual_compression import ContextualCompressionRetriever
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
# Recreate the document objects from the previous data
docs = [
    Document(page_content=(
        """The Grand Canyon is one of the most visited natural wonders in the world.
        Photosynthesis is the process by which green plants convert sunlight into energy.
        Millions of tourists travel to see it every year. The rocks date back millions of years."""
    ), metadata={"source": "Doc1"}),

    Document(page_content=(
        """In medieval Europe, castles were built primarily for defense.
        The chlorophyll in plant cells captures sunlight during photosynthesis.
        Knights wore armor made of metal. Siege weapons were often used to breach castle walls."""
    ), metadata={"source": "Doc2"}),

    Document(page_content=(
        """Basketball was invented by Dr. James Naismith in the late 19th century.
        It was originally played with a soccer ball and peach baskets. NBA is now a global league."""
    ), metadata={"source": "Doc3"}),

    Document(page_content=(
        """The history of cinema began in the late 1800s. Silent films were the earliest form.
        Thomas Edison was among the pioneers. Photosynthesis does not occur in animal cells.
        Modern filmmaking involves complex CGI and sound design."""
    ), metadata={"source": "Doc4"})
]

# %%
# Create a Chroma vector store from the documents
embedding_model = OpenAIEmbeddings()
vectorstore = Chroma.from_documents(docs, embedding_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/learning/lang-chain-structured-output/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:56, in dependable_faiss_import(no_avx2)
#      55     else:
# ---> 56         import faiss
#      57 except ImportError:
#
# ModuleNotFoundError: No module named 'faiss'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Create a FAISS vector store from the documents
#       2 embedding_model = OpenAIEmbeddings()
# ----> 3 vectorstore = FAISS.from_documents(docs, embedding_model)
#
# File ~/Desktop/learning/lang-chain-structured-output/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/Desktop/learning/lang-chain-structured-output/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:1044, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1025 """Construct FAISS wrapper from raw documents.
#    1026
#    1027 This is a user friendly interface that:
#    (...)   1041         faiss = FAISS.from_texts(texts, embeddings)
#    1042 """
#    1043 embeddings = embedding.embed_documents(texts)
# -> 1044 return cls.__from(
#    1045     texts,
#    1046     embeddings,
#    1047     embedding,
#    1048     metadatas=metadatas,
#    1049     ids=ids,
#    1050     **kwargs,
#    1051 )
#
# File ~/Desktop/learning/lang-chain-structured-output/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:996, in FAISS.__from(cls, texts, embeddings, embedding, metadatas, ids, normalize_L2, distance_strategy, **kwargs)
#     984 @classmethod
#     985 def __from(
#     986     cls,
#    (...)    994     **kwargs: Any,
#     995 ) -> FAISS:
# --> 996     faiss = dependable_faiss_import()
#     997     if distance_strategy == DistanceStrategy.MAX_INNER_PRODUCT:
#     998         index = faiss.IndexFlatIP(len(embeddings[0]))
#
# File ~/Desktop/learning/lang-chain-structured-output/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:58, in dependable_faiss_import(no_avx2)
#      56         import faiss
#      57 except ImportError:
# ---> 58     raise ImportError(
#      59         "Could not import faiss python package. "
#      60         "Please install it with `pip install faiss-gpu` (for CUDA supported GPU) "
#      61         "or `pip install faiss-cpu` (depending on Python version)."
#      62     )
#      63 return faiss
#
# ImportError: Could not import faiss python package. Please install it with `pip install faiss-gpu` (for CUDA supported GPU) or `pip install faiss-cpu` (depending on Python version).
